# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

info = pd.read_csv("data.csv")

# %%
# using the info dataFrame, pull each combination of hyperparameters,
#     for each, subtract the best fitness of pacman in stage 3 from the best fitness of pacman in stage 1, 
#      and average those sums over the number of tests

# whichever has the highest average improvement will be considered optimal

# we should check to make sure the one that improves the most 
#  isn't just starting off the worst and getting to a still bad sum

popSizes = [100, 200, 500]
cProbs = [0.01, 0.05, 0.1]
mProbs = [0.01, 0.05, 0.1]
numGenerations = [25, 50, 100]

popSize = 50
probCrossover = 0.001
probMutate = 0.001
numGens = 2

bestps = 0
bestcp = 0
bestmp = 0
bestng = 0

bestImprov = 0
improvements = []

for popSize in popSizes:
    for probCrossover in cProbs:
        for probMutate in mProbs:
            for numGens in numGenerations:
                x = info[info["popSize"] == popSize]
                x = x[x["probCrossover"] == probCrossover]
                x = x[x["probMutate"] == probMutate]
                x = x[x["numGens"] == numGens]
                s1 = x[x["Stage"] == 1.]
                s1 = s1[s1["Generation"] == numGens - 1]
                s3 = x[x["Stage"] == 3.]
                s3 = s3[s3["Generation"] == numGens - 1]
                avgs = []
                top = np.array(s1["Best_Fitness"])
                bottom = np.array(s3["Best_Fitness"])
                for i in range(len(top)):
                    avgs.append(top[i] - bottom[i])
                    #print("")
                avg = np.mean(avgs)
                print(popSize, probCrossover, probMutate, numGens, avg)
                if avg > bestImprov:
                    bestImprov = avg
                    bestps = popSize
                    bestcp = probCrossover
                    bestmp = probMutate
                    bestng = numGens
                improvements.append(avg)
print(bestImprov)
print(bestps)
print(bestcp)
print(bestmp)
print(bestng)
# Out:
# 100 0.01 0.01 25 -0.85
# 100 0.01 0.01 50 -2.4
# 100 0.01 0.01 100 -2.45
# 100 0.01 0.05 25 -9.35
# 100 0.01 0.05 50 -7.6
# 100 0.01 0.05 100 -6.3
# 100 0.01 0.1 25 -8.75
# 100 0.01 0.1 50 -11.75
# 100 0.01 0.1 100 -9.5
# 100 0.05 0.01 25 -1.95
# 100 0.05 0.01 50 1.85
# 100 0.05 0.01 100 1.45
# 100 0.05 0.05 25 -12.05
# 100 0.05 0.05 50 -18.3
# 100 0.05 0.05 100 -12.4
# 100 0.05 0.1 25 -13.9
# 100 0.05 0.1 50 -10.6
# 100 0.05 0.1 100 -17.75
# 100 0.1 0.01 25 -1.8
# 100 0.1 0.01 50 -0.25
# 100 0.1 0.01 100 2.35
# 100 0.1 0.05 25 -10.1
# 100 0.1 0.05 50 -14.45
# 100 0.1 0.05 100 -5.7
# 100 0.1 0.1 25 -14.25
# 100 0.1 0.1 50 -9.1
# 100 0.1 0.1 100 -5.0
# 200 0.01 0.01 25 2.1
# 200 0.01 0.01 50 1.25
# 200 0.01 0.01 100 -0.5
# 200 0.01 0.05 25 -6.55
# 200 0.01 0.05 50 -11.1
# 200 0.01 0.05 100 -6.25
# 200 0.01 0.1 25 -10.95
# 200 0.01 0.1 50 -12.9
# 200 0.01 0.1 100 -11.45
# 200 0.05 0.01 25 3.05
# 200 0.05 0.01 50 1.5
# 200 0.05 0.01 100 0.25
# 200 0.05 0.05 25 -6.55
# 200 0.05 0.05 50 -14.9
# 200 0.05 0.05 100 -7.35
# 200 0.05 0.1 25 -15.85
# 200 0.05 0.1 50 -13.7
# 200 0.05 0.1 100 -10.85
# 200 0.1 0.01 25 -1.9
# 200 0.1 0.01 50 2.75
# 200 0.1 0.01 100 2.05
# 200 0.1 0.05 25 -7.55
# 200 0.1 0.05 50 -8.1
# 200 0.1 0.05 100 -5.45
# 200 0.1 0.1 25 -17.3
# 200 0.1 0.1 50 -11.0
# 200 0.1 0.1 100 -16.45
# 500 0.01 0.01 25 -0.15
# 500 0.01 0.01 50 4.65
# 500 0.01 0.01 100 2.95
# 500 0.01 0.05 25 -9.85
# 500 0.01 0.05 50 -12.6
# 500 0.01 0.05 100 -7.45
# 500 0.01 0.1 25 -10.4
# 500 0.01 0.1 50 -9.15
# 500 0.01 0.1 100 -12.75
# 500 0.05 0.01 25 1.95
# 500 0.05 0.01 50 1.45
# 500 0.05 0.01 100 -1.1
# 500 0.05 0.05 25 -6.15
# 500 0.05 0.05 50 -14.55
# 500 0.05 0.05 100 -12.15
# 500 0.05 0.1 25 -16.0
# 500 0.05 0.1 50 -10.5
# 500 0.05 0.1 100 -10.9
# 500 0.1 0.01 25 1.95
# 500 0.1 0.01 50 0.3
# 500 0.1 0.01 100 0.9
# 500 0.1 0.05 25 -11.0
# 500 0.1 0.05 50 -9.1
# 500 0.1 0.05 100 -13.55
# 500 0.1 0.1 25 -5.8
# 500 0.1 0.1 50 -13.5
# 500 0.1 0.1 100 nan
# 4.65
# 500
# 0.01
# 0.01
# 50
